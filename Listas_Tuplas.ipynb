# %%
Lista_edades=[15,16,13,20,21]

# %%
print(Lista_edades[2])
# Out:
# 13

# %%
Lista_edades.append(43)
print(Lista_edades[:])
Lista_edades.insert(2,32)
# Out:
# [15, 16, 13, 20, 21, 43]

# %%
Lista_edades.remove(13)
print(Lista_edades[:])
# Out:
# [15, 16, 32, 20, 21, 43]

# %%
print(Lista_edades[:])
while 20 in Lista_edades:
    Lista_edades.remove(20)
print(Lista_edades[:])
# Out:
# [15, 16, 32, 20, 21, 43]
# [15, 16, 32, 21, 43]

# %%
print(Lista_edades[:])
Lista_edades.sort()
print(Lista_edades[:])
# Out:
# [15, 16, 32, 21, 43]
# [15, 16, 21, 32, 43]

# %%
print(Lista_edades[:-4])
# Out:
# [15]

# %%
print(Lista_edades[:])
Lista_edades.reverse()
print(Lista_edades[:])
# Out:
# [15, 16, 21, 32, 43]
# [43, 32, 21, 16, 15]

# %%
Lista_edades_2=[3,4,5]
Lista_edades.extend(Lista_edades_2)
print(Lista_edades)
# Out:
# [43, 32, 21, 16, 15, 3, 4, 5]

# %%
for i in Lista_edades:
    print(i)
# Out:
# 43
# 32
# 21
# 16
# 15
# 3
# 4
# 5

# %%
Lista_edades.clear()
print(Lista_edades)
# Out:
# []

# %%
bandera_mayus=False
bandera_numero=False
contra=input("Ingrese una contreseña: ")
for i in "M4rcos":
    if i.isupper()==True:
        bandera_mayus= True 
    elif i.isnumeric()==True:
        bandera_numero=True
    elif i.islower()== True:
        bandera_min=True
if  len(contra)>=6 and len(contra)<=12:
    bandera_long=True

# %%
print(len("Marcos"))
# Out:
# 6

# %%
if bandera_mayus==True and bandera_numero==True and bandera_long==True and bandera_min==True:
    print("Va queriendo ;)")
else:
    print("Pensa de nuevo: ")
# Out:
# Va queriendo ;)
